# %% [markdown]
# <a href="https://colab.research.google.com/github/menezesfelipee/projetos-blue/blob/main/Projeto_1_Detetive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import sleep # Biblioteca importada para fazer alguns efeitos durante a execução do programa.
from google.colab import output # Serve para limpar a tela do console durante a execução do programa.
from tqdm import tqdm # Bibliteca para barra de progesso
print('''
██████╗ ███████╗████████╗███████╗████████╗██╗██╗   ██╗███████╗
██╔══██╗██╔════╝╚══██╔══╝██╔════╝╚══██╔══╝██║██║   ██║██╔════╝
██║  ██║█████╗     ██║   █████╗     ██║   ██║██║   ██║█████╗  
██║  ██║██╔══╝     ██║   ██╔══╝     ██║   ██║╚██╗ ██╔╝██╔══╝  
██████╔╝███████╗   ██║   ███████╗   ██║   ██║ ╚████╔╝ ███████╗
╚═════╝ ╚══════╝   ╚═╝   ╚══════╝   ╚═╝   ╚═╝  ╚═══╝  ╚══════╝
''')
intro1 = '''Olá, eu sou o Detetive Felipe Menezes.
Sou um Agente Bluemer Especializado em casos de muita complexidade com 10 anos de experiência na área.

Hoje estamos aqui contigo na Delegacia Virtual para termos mais informações do caso.
Contamos com a sua contribuição para que esse caso seja solucinado o mais brevemente possível.'''
for a in intro1: # Utilizando laço somente para mostrar letra por letra
  print(a, end='')
  sleep(0.05)
sleep(5)
output.clear()
intro2 = 'Primeiramente, preciso confirmar o seu nome com o que possuo no meu banco de dados.'
for a in intro2:
  print(a, end='')
  sleep(0.05)
sleep(3)
nome = input('\nDigite seu primeiro nome, por gentiliza: ').capitalize().strip()
print('\nAguarde um instante enquanto verificamos.')
sleep(1)
for i in tqdm(nome): # Aparece uma barra de progresso
    sleep(1)
sleep(1)
output.clear()
intro3 = f'''Tudo certo, {nome}. Vamos prosseguir.
Farei 5 perguntas para você que nos ajudará a te definir melhor nesse caso.
Lembre-se que a mentira nunca é uma boa escolha!

'''
for a in intro3:
  print(a, end='')
  sleep(0.05)
sleep(3)
print('=-' *45)
print('')
# Iniciando a parte da lógica
cont = 0 # Contador de respostas positivas, iniciando em zero
pergunta1 = input('Você telefonou para a vítima? [S/n] ').strip().upper()[0]
if pergunta1 == 'S':
  cont += 1 # Se a resposta for positiva, acrescenta uma unidade ao contador
print('')
print('=-' *45)
print('')
pergunta2 = input('Você esteve no local do crime? [S/n] ').strip().upper()[0]
if pergunta2 == 'S':
  cont += 1
print('')
print('=-' *45)
print('')
pergunta3 = input('Você mora perto da vítima? [S/n] ').strip().upper()[0]
if pergunta3 == 'S':
  cont += 1
print('')
print('=-' *45)
print('')
pergunta4 = input('Você devia para a vítima? [S/n] ').strip().upper()[0]
if pergunta4 == 'S':
  cont += 1
print('')
print('=-' *45)
print('')
pergunta5 = input('Você já trabalhou com a vítima? [S/n] ').strip().upper()[0]
if pergunta5 == 'S':
  cont += 1
print('')
print('=-' *45)
print('')
sleep(2)
print('''
Aguarde um instante enquanto estamos fazendo as correlações necessárias.
''')
  ░   ▒   ░  ░  ░  ░  ░  ░    ░   ▒   ░  ░  ░  ░  ░  ░   ▒ ░   ░   ░ ░ ░ ░ ░ ▒      ░     ░     ░ 
      ░  ░      ░        ░        ░  ░      ░        ░   ░           ░     ░ ░   ░     ░     ░    
''')
else:
  print('''
██╗███╗   ██╗ ██████╗  ██████╗███████╗███╗   ██╗████████╗███████╗██╗
██║████╗  ██║██╔═══██╗██╔════╝██╔════╝████╗  ██║╚══██╔══╝██╔════╝██║
██║██╔██╗ ██║██║   ██║██║     █████╗  ██╔██╗ ██║   ██║   █████╗  ██║
██║██║╚██╗██║██║   ██║██║     ██╔══╝  ██║╚██╗██║   ██║   ██╔══╝  ╚═╝
██║██║ ╚████║╚██████╔╝╚██████╗███████╗██║ ╚████║   ██║   ███████╗██╗
╚═╝╚═╝  ╚═══╝ ╚═════╝  ╚═════╝╚══════╝╚═╝  ╚═══╝   ╚═╝   ╚══════╝╚═╝
''')
# Out:
#  ▄▄▄        ██████   ██████  ▄▄▄        ██████   ██████  ██▓ ███▄    █  ▒█████   ▐██▌  ▐██▌  ▐██▌
# ▒████▄    ▒██    ▒ ▒██    ▒ ▒████▄    ▒██    ▒ ▒██    ▒ ▓██▒ ██ ▀█   █ ▒██▒  ██▒ ▐██▌  ▐██▌  ▐██▌
# ▒██  ▀█▄  ░ ▓██▄   ░ ▓██▄   ▒██  ▀█▄  ░ ▓██▄   ░ ▓██▄   ▒██▒▓██  ▀█ ██▒▒██░  ██▒ ▐██▌  ▐██▌  ▐██▌
# ░██▄▄▄▄██   ▒   ██▒  ▒   ██▒░██▄▄▄▄██   ▒   ██▒  ▒   ██▒░██░▓██▒  ▐▌██▒▒██   ██░ ▓██▒  ▓██▒  ▓██▒
#  ▓█   ▓██▒▒██████▒▒▒██████▒▒ ▓█   ▓██▒▒██████▒▒▒██████▒▒░██░▒██░   ▓██░░ ████▓▒░ ▒▄▄   ▒▄▄   ▒▄▄
#  ▒▒   ▓▒█░▒ ▒▓▒ ▒ ░▒ ▒▓▒ ▒ ░ ▒▒   ▓▒█░▒ ▒▓▒ ▒ ░▒ ▒▓▒ ▒ ░░▓  ░ ▒░   ▒ ▒ ░ ▒░▒░▒░  ░▀▀▒  ░▀▀▒  ░▀▀▒
#   ▒   ▒▒ ░░ ░▒  ░ ░░ ░▒  ░ ░  ▒   ▒▒ ░░ ░▒  ░ ░░ ░▒  ░ ░ ▒ ░░ ░░   ░ ▒░  ░ ▒ ▒░  ░  ░  ░  ░  ░  ░
#   ░   ▒   ░  ░  ░  ░  ░  ░    ░   ▒   ░  ░  ░  ░  ░  ░   ▒ ░   ░   ░ ░ ░ ░ ░ ▒      ░     ░     ░
#       ░  ░      ░        ░        ░  ░      ░        ░   ░           ░     ░ ░   ░     ░     ░
